# %% [markdown]
# # Sales Anlysis

# %% [markdown]
# #### Import Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ##### merging 12 months of data into a single table

# %%
files = [file for file in os.listdir('/users/musabbelahouel/documents/python_data_analysis/Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data')]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('/users/musabbelahouel/documents/python_data_analysis/Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data, df])
    
all_months_data.to_csv("all_data.csv", index = False)

# %% [markdown]
# #### Read in updated data frame

# %%
all_data = pd.read_csv('/users/musabbelahouel/documents/python_data_analysis/all_data.csv', index_col = 'Order ID')

# %%
all_data.head()
# Out:
#                        Product Quantity Ordered Price Each      Order Date  \
# Order ID
# 295665      Macbook Pro Laptop                1       1700  12/30/19 00:01
# 295666      LG Washing Machine                1      600.0  12/29/19 07:03
# 295667    USB-C Charging Cable                1      11.95  12/12/19 18:21
# 295668        27in FHD Monitor                1     149.99  12/22/19 15:13
# 295669    USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                                 Purchase Address
# Order ID
# 295665    136 Church St, New York City, NY 10001
# 295666       562 2nd St, New York City, NY 10001
# 295667      277 Main St, New York City, NY 10001
# 295668       410 6th St, San Francisco, CA 94016
# 295669             43 Hill St, Atlanta, GA 30301

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186850 entries, 295665 to 222909
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Product           186305 non-null  object
#  1   Quantity Ordered  186305 non-null  object
#  2   Price Each        186305 non-null  object
#  3   Order Date        186305 non-null  object
#  4   Purchase Address  186305 non-null  object
# dtypes: object(5)
# memory usage: 8.6+ MB

# %% [markdown]
# ##### Augment Data with additional columns

# %% [markdown]
# #### Add month column

# %%
all_data['Month'] = all_data['Month'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#                        Product Quantity Ordered Price Each      Order Date  \
# Order ID
# 295665      Macbook Pro Laptop                1       1700  12/30/19 00:01
# 295666      LG Washing Machine                1      600.0  12/29/19 07:03
# 295667    USB-C Charging Cable                1      11.95  12/12/19 18:21
# 295668        27in FHD Monitor                1     149.99  12/22/19 15:13
# 295669    USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                                 Purchase Address  Month
# Order ID
# 295665    136 Church St, New York City, NY 10001     12
# 295666       562 2nd St, New York City, NY 10001     12
# 295667      277 Main St, New York City, NY 10001     12
# 295668       410 6th St, San Francisco, CA 94016     12
# 295669             43 Hill St, Atlanta, GA 30301     12

# %% [markdown]
# ##### Clean up the data

# %% [markdown]
# ##### Drop rows with NaN's

# %%
null_df = all_data[all_data.isna().any(axis=1)]
null_df.head()

all_data = all_data.dropna(how = 'all')
all_data.head()
# Out:
#                        Product Quantity Ordered Price Each      Order Date  \
# Order ID
# 295665      Macbook Pro Laptop                1       1700  12/30/19 00:01
# 295666      LG Washing Machine                1      600.0  12/29/19 07:03
# 295667    USB-C Charging Cable                1      11.95  12/12/19 18:21
# 295668        27in FHD Monitor                1     149.99  12/22/19 15:13
# 295669    USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                                 Purchase Address Month
# Order ID
# 295665    136 Church St, New York City, NY 10001    12
# 295666       562 2nd St, New York City, NY 10001    12
# 295667      277 Main St, New York City, NY 10001    12
# 295668       410 6th St, San Francisco, CA 94016    12
# 295669             43 Hill St, Atlanta, GA 30301    12

# %% [markdown]
# ##### Find 'Or' and delete it

# %%
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data.head()
# Out:
#                        Product Quantity Ordered Price Each      Order Date  \
# Order ID
# 295665      Macbook Pro Laptop                1       1700  12/30/19 00:01
# 295666      LG Washing Machine                1      600.0  12/29/19 07:03
# 295667    USB-C Charging Cable                1      11.95  12/12/19 18:21
# 295668        27in FHD Monitor                1     149.99  12/22/19 15:13
# 295669    USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                                 Purchase Address Month
# Order ID
# 295665    136 Church St, New York City, NY 10001    12
# 295666       562 2nd St, New York City, NY 10001    12
# 295667      277 Main St, New York City, NY 10001    12
# 295668       410 6th St, San Francisco, CA 94016    12
# 295669             43 Hill St, Atlanta, GA 30301    12

# %% [markdown]
# ###### Add a sales column

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head(20)
# Out:
#                              Product  Quantity Ordered  Price Each  \
# Order ID
# 295665            Macbook Pro Laptop                 1     1700.00
# 295666            LG Washing Machine                 1      600.00
# 295667          USB-C Charging Cable                 1       11.95
# 295668              27in FHD Monitor                 1      149.99
# 295669          USB-C Charging Cable                 1       11.95
# 295670         AA Batteries (4-pack)                 1        3.84
# 295671          USB-C Charging Cable                 1       11.95
# 295672          USB-C Charging Cable                 2       11.95
# 295673    Bose SoundSport Headphones                 1       99.99
# 295674        AAA Batteries (4-pack)                 4        2.99
# 295675          USB-C Charging Cable                 2       11.95
# 295676               ThinkPad Laptop                 1      999.99
# 295677         AA Batteries (4-pack)                 2        3.84
# 295678        AAA Batteries (4-pack)                 2        2.99
# 295679          USB-C Charging Cable                 1       11.95
# 295680      Lightning Charging Cable                 1       14.95
# 295681                  Google Phone                 1      600.00
# 295681          USB-C Charging Cable                 1       11.95
# 295681    Bose SoundSport Headphones                 1       99.99
# 295681              Wired Headphones                 1       11.99
#
#               Order Date                           Purchase Address  Month  \
# Order ID
# 295665    12/30/19 00:01     136 Church St, New York City, NY 10001     12
# 295666    12/29/19 07:03        562 2nd St, New York City, NY 10001     12
# 295667    12/12/19 18:21       277 Main St, New York City, NY 10001     12
# 295668    12/22/19 15:13        410 6th St, San Francisco, CA 94016     12
# 295669    12/18/19 12:38              43 Hill St, Atlanta, GA 30301     12
# 295670    12/31/19 22:58  200 Jefferson St, New York City, NY 10001     12
# 295671    12/16/19 15:10            928 12th St, Portland, OR 97035     12
# 295672    12/13/19 09:29           813 Hickory St, Dallas, TX 75001     12
# 295673    12/15/19 23:26            718 Wilson St, Dallas, TX 75001     12
# 295674    12/28/19 11:51                77 7th St, Dallas, TX 75001     12
# 295675    12/13/19 13:52        594 1st St, San Francisco, CA 94016     12
# 295676    12/28/19 17:19      410 Lincoln St, Los Angeles, CA 90001     12
# 295677    12/20/19 19:19              866 Pine St, Boston, MA 02215     12
# 295678    12/06/19 09:38           187 Lincoln St, Dallas, TX 75001     12
# 295679    12/25/19 09:39               902 2nd St, Dallas, TX 75001     12
# 295680    12/01/19 14:30              338 Main St, Austin, TX 73301     12
# 295681    12/25/19 12:37                79 Elm St, Boston, MA 02215     12
# 295681    12/25/19 12:37                79 Elm St, Boston, MA 02215     12
# 295681    12/25/19 12:37                79 Elm St, Boston, MA 02215     12
# 295681    12/25/19 12:37                79 Elm St, Boston, MA 02215     12
#
#             Sales
# Order ID
# 295665    1700.00
# 295666     600.00
# 295667      11.95
# 295668     149.99
# 295669      11.95
# 295670       3.84
# 295671      11.95
# 295672      23.90
# 295673      99.99
# 295674      11.96
# 295675      23.90
# 295676     999.99
# 295677       7.68
# 295678       5.98
# 295679      11.95
# 295680      14.95
# 295681     600.00
# 295681      11.95
# 295681      99.99
# 295681      11.99

# %% [markdown]
# ##### Convert quantity ordered and price each from str to to the correct data type

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# ###### What was the best month for sales and how much money was made during that month?

# %%
results = all_data.groupby('Month').sum()
results.head(13)
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
months = range(1,13)
plt.bar(months, results['Sales'])
plt.xticks(months)
plt.xlabel('Month Number')
plt.ylabel('Sales in USD ($)')
plt.title('Total Sales in each month')
plt.show()

# %% [markdown]
# ###### Maybe, this is because Chrismas is in December. Ther will probably be quite a few factors contributing towards why december is the month with the highest sales. So, quite a few hypothesis could be established from studying this graph.

# %% [markdown]
# ##### Question 2: What US city had the highest number of sales?

# %% [markdown]
# ##### Drop city code column

# %%
all_data = all_data.drop(['City Code'])
# Out:
#                        Product  Quantity Ordered  Price Each      Order Date  \
# Order ID
# 295665      Macbook Pro Laptop                 1     1700.00  12/30/19 00:01
# 295666      LG Washing Machine                 1      600.00  12/29/19 07:03
# 295667    USB-C Charging Cable                 1       11.95  12/12/19 18:21
# 295668        27in FHD Monitor                 1      149.99  12/22/19 15:13
# 295669    USB-C Charging Cable                 1       11.95  12/18/19 12:38
#
#                                 Purchase Address  Month    Sales State Code
# Order ID
# 295665    136 Church St, New York City, NY 10001     12  1700.00         NY
# 295666       562 2nd St, New York City, NY 10001     12   600.00         NY
# 295667      277 Main St, New York City, NY 10001     12    11.95         NY
# 295668       410 6th St, San Francisco, CA 94016     12   149.99         CA
# 295669             43 Hill St, Atlanta, GA 30301     12    11.95         GA

# %% [markdown]
# ##### Make a state column

# %%
all_data['State Code'] = all_data['Purchase Address'].str[-8:-6]
all_data.head(100)
# Out:
#                            Product  Quantity Ordered  Price Each  \
# Order ID
# 295665          Macbook Pro Laptop                 1     1700.00
# 295666          LG Washing Machine                 1      600.00
# 295667        USB-C Charging Cable                 1       11.95
# 295668            27in FHD Monitor                 1      149.99
# 295669        USB-C Charging Cable                 1       11.95
# ...                            ...               ...         ...
# 295751      AAA Batteries (4-pack)                 1        2.99
# 295752                Google Phone                 1      600.00
# 295753      34in Ultrawide Monitor                 1      379.99
# 295753    Lightning Charging Cable                 1       14.95
# 295754    Lightning Charging Cable                 1       14.95
#
#               Order Date                        Purchase Address  Month  \
# Order ID
# 295665    12/30/19 00:01  136 Church St, New York City, NY 10001     12
# 295666    12/29/19 07:03     562 2nd St, New York City, NY 10001     12
# 295667    12/12/19 18:21    277 Main St, New York City, NY 10001     12
# 295668    12/22/19 15:13     410 6th St, San Francisco, CA 94016     12
# 295669    12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12
# ...                  ...                                     ...    ...
# 295751    12/29/19 11:03   922 Hickory St, Los Angeles, CA 90001     12
# 295752    12/11/19 12:29         341 Forest St, Dallas, TX 75001     12
# 295753    12/25/19 06:26     365 Washington St, Dallas, TX 75001     12
# 295753    12/25/19 06:26     365 Washington St, Dallas, TX 75001     12
# 295754    12/07/19 19:26         502 Cherry St, Austin, TX 73301     12
#
#             Sales City Code State Code
# Order ID
# 295665    1700.00        NY         NY
# 295666     600.00        NY         NY
# 295667      11.95        NY         NY
# 295668     149.99        CA         CA
# 295669      11.95        GA         GA
# ...           ...       ...        ...
# 295751       2.99        CA         CA
# 295752     600.00        TX         TX
# 295753     379.99        TX         TX
# 295753      14.95        TX         TX
# 295754      14.95        TX         TX
#
# [100 rows x 9 columns]

# %%
state = all_data.groupby('State Code').sum()
state.head(13)
# Out:
#             Quantity Ordered    Price Each   Month         Sales
# State Code
# CA                     83528  1.363290e+07  523845  1.371477e+07
# GA                     16602  2.779908e+06  104794  2.795499e+06
# MA                     22528  3.637410e+06  141112  3.661642e+06
# ME                      2750  4.471893e+05   17144  4.497583e+05
# NY                     27932  4.635371e+06  175741  4.664317e+06
# OR                     11303  1.860558e+06   70621  1.870732e+06
# TX                     27883  4.562501e+06  174449  4.587557e+06
# WA                     16553  2.733296e+06  104941  2.747755e+06

# %% [markdown]
# ##### Make a city name column

# %%
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split(' ')[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: get_city(x) + ' (' + get_state(x)+')')
all_data.head(100)
# Out:
#                            Product  Quantity Ordered  Price Each  \
# Order ID
# 295665          Macbook Pro Laptop                 1     1700.00
# 295666          LG Washing Machine                 1      600.00
# 295667        USB-C Charging Cable                 1       11.95
# 295668            27in FHD Monitor                 1      149.99
# 295669        USB-C Charging Cable                 1       11.95
# ...                            ...               ...         ...
# 295751      AAA Batteries (4-pack)                 1        2.99
# 295752                Google Phone                 1      600.00
# 295753      34in Ultrawide Monitor                 1      379.99
# 295753    Lightning Charging Cable                 1       14.95
# 295754    Lightning Charging Cable                 1       14.95
#
#               Order Date                        Purchase Address  Month  \
# Order ID
# 295665    12/30/19 00:01  136 Church St, New York City, NY 10001     12
# 295666    12/29/19 07:03     562 2nd St, New York City, NY 10001     12
# 295667    12/12/19 18:21    277 Main St, New York City, NY 10001     12
# 295668    12/22/19 15:13     410 6th St, San Francisco, CA 94016     12
# 295669    12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12
# ...                  ...                                     ...    ...
# 295751    12/29/19 11:03   922 Hickory St, Los Angeles, CA 90001     12
# 295752    12/11/19 12:29         341 Forest St, Dallas, TX 75001     12
# 295753    12/25/19 06:26     365 Washington St, Dallas, TX 75001     12
# 295753    12/25/19 06:26     365 Washington St, Dallas, TX 75001     12
# 295754    12/07/19 19:26         502 Cherry St, Austin, TX 73301     12
#
#             Sales State Code                 City
# Order ID
# 295665    1700.00         NY   New York City (NY)
# 295666     600.00         NY   New York City (NY)
# 295667      11.95         NY   New York City (NY)
# 295668     149.99         CA   San Francisco (CA)
# 295669      11.95         GA         Atlanta (GA)
# ...           ...        ...                  ...
# 295751       2.99         CA     Los Angeles (CA)
# 295752     600.00         TX          Dallas (TX)
# 295753     379.99         TX          Dallas (TX)
# 295753      14.95         TX          Dallas (TX)
# 295754      14.95         TX          Austin (TX)
#
# [100 rows x 9 columns]

# %% [markdown]
# ##### Using f string to simplify the operation

# %%
all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
all_data.head()
# Out:
#                        Product  Quantity Ordered  Price Each      Order Date  \
# Order ID
# 295665      Macbook Pro Laptop                 1     1700.00  12/30/19 00:01
# 295666      LG Washing Machine                 1      600.00  12/29/19 07:03
# 295667    USB-C Charging Cable                 1       11.95  12/12/19 18:21
# 295668        27in FHD Monitor                 1      149.99  12/22/19 15:13
# 295669    USB-C Charging Cable                 1       11.95  12/18/19 12:38
#
#                                 Purchase Address  Month    Sales State Code  \
# Order ID
# 295665    136 Church St, New York City, NY 10001     12  1700.00         NY
# 295666       562 2nd St, New York City, NY 10001     12   600.00         NY
# 295667      277 Main St, New York City, NY 10001     12    11.95         NY
# 295668       410 6th St, San Francisco, CA 94016     12   149.99         CA
# 295669             43 Hill St, Atlanta, GA 30301     12    11.95         GA
#
#                          City
# Order ID
# 295665     New York City (NY)
# 295666     New York City (NY)
# 295667     New York City (NY)
# 295668     San Francisco (CA)
# 295669           Atlanta (GA)

# %% [markdown]
# ##### This is the simple method

# %%
# all_data['City'] = all_data['Purchase Address'].apply(lambda x: x.split(',')[1])
# all_data.head(100)

# %%
all_data.drop(['State Code'], axis = 1, inplace = True)

# %%
all_data.head()
# Out:
#                        Product  Quantity Ordered  Price Each      Order Date  \
# Order ID
# 295665      Macbook Pro Laptop                 1     1700.00  12/30/19 00:01
# 295666      LG Washing Machine                 1      600.00  12/29/19 07:03
# 295667    USB-C Charging Cable                 1       11.95  12/12/19 18:21
# 295668        27in FHD Monitor                 1      149.99  12/22/19 15:13
# 295669    USB-C Charging Cable                 1       11.95  12/18/19 12:38
#
#                                 Purchase Address  Month    Sales  \
# Order ID
# 295665    136 Church St, New York City, NY 10001     12  1700.00
# 295666       562 2nd St, New York City, NY 10001     12   600.00
# 295667      277 Main St, New York City, NY 10001     12    11.95
# 295668       410 6th St, San Francisco, CA 94016     12   149.99
# 295669             43 Hill St, Atlanta, GA 30301     12    11.95
#
#                          City
# Order ID
# 295665     New York City (NY)
# 295666     New York City (NY)
# 295667     New York City (NY)
# 295668     San Francisco (CA)
# 295669           Atlanta (GA)

# %%
city = all_data.groupby('City').sum().reset_index()
city.head(20)
# Out:
#                   City  Quantity Ordered    Price Each   Month         Sales
# 0         Atlanta (GA)             16602  2.779908e+06  104794  2.795499e+06
# 1          Austin (TX)             11153  1.809874e+06   69829  1.819582e+06
# 2          Boston (MA)             22528  3.637410e+06  141112  3.661642e+06
# 3          Dallas (TX)             16730  2.752628e+06  104620  2.767975e+06
# 4     Los Angeles (CA)             33289  5.421435e+06  208325  5.452571e+06
# 5   New York City (NY)             27932  4.635371e+06  175741  4.664317e+06
# 6        Portland (ME)              2750  4.471893e+05   17144  4.497583e+05
# 7        Portland (OR)             11303  1.860558e+06   70621  1.870732e+06
# 8   San Francisco (CA)             50239  8.211462e+06  315520  8.262204e+06
# 9         Seattle (WA)             16553  2.733296e+06  104941  2.747755e+06

# %%
plt.bar(city['City'], city['Sales'])
plt.xlabel('City')
plt.ylabel('Sales in USD ($)')
plt.xticks(rotation=45, ha='right')
plt.title('Total Sales by City')
plt.show()

# %% [markdown]
# ###### Maybe, San Fransisco is the city with the highest sales because; silicon valley needs more electronics, tech to advertise is better, people are richer etc. We could start to for some sort of hypothesis based on this graph.
#
# ###### Maybe, Portland has the lowest sales because; its the smallest city or advertising is the poorest.

# %% [markdown]
# ##### What time should we display advertisments to maximise the likelyhood of customers buying products?

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

# %%
all_data['Hour'] = (all_data['Order Date']).dt.hour
all_data['Minute'] = (all_data['Order Date']).dt.minute
all_data.head()
# Out:
#                        Product  Quantity Ordered  Price Each  \
# Order ID
# 295665      Macbook Pro Laptop                 1     1700.00
# 295666      LG Washing Machine                 1      600.00
# 295667    USB-C Charging Cable                 1       11.95
# 295668        27in FHD Monitor                 1      149.99
# 295669    USB-C Charging Cable                 1       11.95
#
#                   Order Date                        Purchase Address  Month  \
# Order ID
# 295665   2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 295666   2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 295667   2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 295668   2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 295669   2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#             Sales                 City  Hour  Minute
# Order ID
# 295665    1700.00   New York City (NY)     0       1
# 295666     600.00   New York City (NY)     7       3
# 295667      11.95   New York City (NY)    18      21
# 295668     149.99   San Francisco (CA)    15      13
# 295669      11.95         Atlanta (GA)    12      38

# %%
hour = all_data.groupby(['Hour']).count()
hour.reset_index(inplace = True)

# %%
#plt.bar(hour['Hour'], hour['Sales'])
plt.plot(hour['Hour'], hour['Sales'])
plt.grid()
plt.xlabel('Hour')
plt.ylabel('Sales in USD ($)')
plt.xticks(hour['Hour'])
plt.title('Total Sales by Hour')
plt.show()

# %%
# based on this chart my recommendation would be to advertise before 11am or 7pm, 
# because thats where the peaks are.
# This is the outcome for every city. It will be worth working out what time is best 
# for each city.

# %% [markdown]
# ##### What products are most often sold together?
